# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from modeler.modeler import Modeler as m

# %%
data = pd.read_csv("Twitch_game_data.csv")

# %%
data["date"] = [datetime(int(row[1]["Year"]),int(row[1]["Month"]),1) for row in data.iterrows()]
data["Hours_watched"] = [int(x) for x in data["Hours_watched"]]
data["Hours_Streamed"] = [int(x.split(" ")[0]) for x in data["Hours_Streamed"]]

# %%
data["efficiency"] = data["Hours_watched"] / data["Hours_Streamed"]

# %%
gamz = []
metric = "Avg_viewers"
for game in data["Game"].unique():
    game_data = data[data["Game"]==game]
    for i in range(3):
        game_data[str(i)] = game_data[metric].shift(1)
    game_data["y"] = game_data[metric].shift(-2)
    gamz.append(game_data)
# Out:
# <ipython-input-52-463c441288ba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   game_data[str(i)] = game_data["Hours_watched"].shift(1)
# <ipython-input-52-463c441288ba>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   game_data["y"] = game_data["Hours_watched"].shift(-2)

# %%
model_data = pd.concat(gamz).dropna()
prediction_data = pd.concat(gamz)

# %%
model_data.columns
# Out:
# Index(['Rank', 'Game', 'Month', 'Year', 'Hours_watched', 'Hours_Streamed',
#        'Peak_viewers', 'Peak_channels', 'Streamers', 'Avg_viewers',
#        'Avg_channels', 'Avg_viewer_ratio', 'date', 'efficiency', '0', '1', '2',
#        'y'],
#       dtype='object')

# %%
model_data = model_data.sample(frac=1)

# %%
training_data = model_data.iloc[:int(model_data.index.size * 0.7)]
testing_data = model_data.iloc[int(model_data.index.size * 0.7):]
factors = ["Month","Hours_watched","Streamers","Avg_viewers","Avg_channels","0","1","2"]

# %%
X = training_data[factors]
y = training_data[["y"]]
sk_model = m.sk_regression({"X":X,"y":y})
xgb_model = m.xgb_regression({"X":X,"y":y})
# Out:
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:683: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:683: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:683: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:683: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:683: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 674, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.81633278        nan 0.81633278]
#   warnings.warn(

# %%
sk_model.append(xgb_model)

# %%
model = pd.DataFrame(sk_model).sort_values(by="score",ascending=False).iloc[0]

# %%
predictions = model["model"].predict(testing_data[factors])

# %%
testing_data["predictions"] = [x[0] for x in predictions]
testing_data.sort_values("date",ascending=True,inplace=True)
# Out:
# <ipython-input-63-0c61b2cb4cc8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data["predictions"] = [x[0] for x in predictions]
# <ipython-input-63-0c61b2cb4cc8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_data.sort_values("date",ascending=True,inplace=True)

# %%
upcoming_data = prediction_data[prediction_data["date"] >= datetime(2021,6,1)]

# %%
upcoming_data.drop("y",axis=1,inplace=True)
# Out:
# c:\users\eric\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
upcoming_data.dropna(inplace=True)
# Out:
# <ipython-input-66-ca08578af31d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upcoming_data.dropna(inplace=True)

# %%
upcoming_predictions = model["model"].predict(upcoming_data[factors])
upcoming_data["predictions"] = [x[0] for x in upcoming_predictions]
upcoming_data["score"] = model["score"]
# Out:
# <ipython-input-73-373f451345ca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upcoming_data["predictions"] = [x[0] for x in upcoming_predictions]
# <ipython-input-73-373f451345ca>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upcoming_data["score"] = model["score"]

# %%
upcoming_data["gain"] = (upcoming_data["predictions"] - upcoming_data[metric]) / upcoming_data[metric]
# Out:
# <ipython-input-74-613cf2a6df98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   upcoming_data["gain"] = (upcoming_data["predictions"] - upcoming_data["Hours_watched"]) / upcoming_data["Hours_watched"]

# %%
upcoming_data.sort_values("gain",ascending=False).head(20)
# Out:
#        Rank                           Game  Month  Year  Hours_watched  \
# 13046    47          Resident Evil Village      6  2021        4694663
# 13193   194                      Biomutant      6  2021         719024
# 13120   121         Subnautica: Below Zero      6  2021        1403450
# 13185   186      Resident Evil 7 biohazard      6  2021         764140
# 13199   200                  Tabletop RPGs      6  2021         688130
# 13084    85                  Knockout City      6  2021        2194194
# 13161   162                   Dread Hunger      6  2021         878374
# 13153   154            Monster Hunter Rise      6  2021         913315
# 13126   127             Motorsport Manager      6  2021        1280209
# 13194   195                  Overcooked! 2      6  2021         715442
# 13198   199           Little Nightmares II      6  2021         695130
# 13060    61                  Path of Exile      6  2021        3630759
# 13190   191                  Demon's Souls      6  2021         728827
# 13096    97  Mass Effect Legendary Edition      6  2021        1913473
# 13101   102                      Days Gone      6  2021        1744926
# 13176   177                       Miitopia      6  2021         797300
# 13189   190                Project Zomboid      6  2021         732815
# 13147   148                  7 Days to Die      6  2021         971682
# 13195   196                    War Thunder      6  2021         704459
# 13088    89                         Roblox      6  2021        2103682
#
#        Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 13046          234473         50271           1072      32479         6529
# 13193          102352         19200            719      12208         1000
# 13120           73478         14327            360       8477         1951
# 13185           84771         31608            299      15370         1062
# 13199           23602         20018            122       2567          957
# 13084          179088         99690           1144      33414         3051
# 13161            6847         49594             33        691         1221
# 13153           74045         26630            275       7768         1270
# 13126            3334         37447             17        360         1780
# 13194           79740         31697            823      29331          995
# 13198           27581         43518            105       6128          966
# 13060           94545         30352            531       4946         5049
# 13190           28065         23199             88       3640         1013
# 13096          201398         10976            731      12550         2661
# 13101          139526         20177            559      12762         2426
# 13176           22955         17956            113       2683         1108
# 13189           21565          8293             63       1873         1019
# 13147          124726         13911            315       9857         1351
# 13195           73613          8812            223       7035          979
# 13088          372196         20358            885      58979         2925
#
#        Avg_channels  Avg_viewer_ratio       date  efficiency           0  \
# 13046           326             20.02 2021-06-01   20.022190  50416020.0
# 13193           142              7.03 2021-06-01    7.025012   5529785.0
# 13120           102             19.10 2021-06-01   19.100275  10802952.0
# 13185           117              9.01 2021-06-01    9.014168   3449793.0
# 13199            32             29.16 2021-06-01   29.155580   2801165.0
# 13084           249             12.25 2021-06-01   12.252044   6312930.0
